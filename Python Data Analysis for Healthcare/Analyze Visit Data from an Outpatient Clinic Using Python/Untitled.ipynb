# %%
import pandas as pd

# %%
df_visits = pd.read_csv("data/raw/Demo Hospital Outpatient Data_NHC.csv")
df_visits
# Out:
#         Visit_Date  Patient_ID  Age  Gender  \
# 0       2020-05-06      688923   68  Female
# 1       2018-08-04      886361   62  Female
# 2       2021-04-10      464823   70  Female
# 3       2021-10-01      655214    8  Female
# 4       2018-04-30      454666   24    Male
# ...            ...         ...  ...     ...
# 999995  2018-09-30      385435    9    Male
# 999996  2020-05-08      117261   29  Female
# 999997  2019-12-31      594613   39  Female
# 999998  2019-11-04      152179   39  Female
# 999999  2019-05-11      370584   76  Female
#
#                                 Diagnosis  Has_Insurance  Postcode  \
# 0                                Diabetes           True     20006
# 1                 Urinary Tract Infection          False     20005
# 2       Upper Respiratory Tract Infection           True     10003
# 3       Upper Respiratory Tract Infection          False     10006
# 4                                 Malaria           True     10006
# ...

# %%
df_visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 13 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   Visit_Date     1000000 non-null  object
#  1   Patient_ID     1000000 non-null  int64
#  2   Age            1000000 non-null  int64
#  3   Gender         1000000 non-null  object
#  4   Diagnosis      1000000 non-null  object
#  5   Has_Insurance  1000000 non-null  bool
#  6   Postcode       1000000 non-null  int64
#  7   Total_Cost     1000000 non-null  float64
#  8   Registration   1000000 non-null  int64
#  9   Nursing        1000000 non-null  int64
#  10  Laboratory     1000000 non-null  int64
#  11  Consultation   1000000 non-null  int64
#  12  Pharmacy       1000000 non-null  int64
# dtypes: bool(1), float64(1), int64(8), object(3)
# memory usage: 92.5+ MB

# %%
df_visits.isna()
# Out:
#         Visit_Date  Patient_ID    Age  Gender  Diagnosis  Has_Insurance  \
# 0            False       False  False   False      False          False
# 1            False       False  False   False      False          False
# 2            False       False  False   False      False          False
# 3            False       False  False   False      False          False
# 4            False       False  False   False      False          False
# ...            ...         ...    ...     ...        ...            ...
# 999995       False       False  False   False      False          False
# 999996       False       False  False   False      False          False
# 999997       False       False  False   False      False          False
# 999998       False       False  False   False      False          False
# 999999       False       False  False   False      False          False
#
#         Postcode  Total_Cost  Registration  Nursing  Laboratory  Consultation  \
# ...

# %%
df_visits.isna().sum()
# Out:
# Visit_Date       0
# Patient_ID       0
# Age              0
# Gender           0
# Diagnosis        0
# Has_Insurance    0
# Postcode         0
# Total_Cost       0
# Registration     0
# Nursing          0
# Laboratory       0
# Consultation     0
# Pharmacy         0
# dtype: int64

# %%
df_visits.dropna()
# Out:
#         Visit_Date  Patient_ID  Age  Gender  \
# 0       2020-05-06      688923   68  Female
# 1       2018-08-04      886361   62  Female
# 2       2021-04-10      464823   70  Female
# 3       2021-10-01      655214    8  Female
# 4       2018-04-30      454666   24    Male
# ...            ...         ...  ...     ...
# 999995  2018-09-30      385435    9    Male
# 999996  2020-05-08      117261   29  Female
# 999997  2019-12-31      594613   39  Female
# 999998  2019-11-04      152179   39  Female
# 999999  2019-05-11      370584   76  Female
#
#                                 Diagnosis  Has_Insurance  Postcode  \
# 0                                Diabetes           True     20006
# 1                 Urinary Tract Infection          False     20005
# 2       Upper Respiratory Tract Infection           True     10003
# 3       Upper Respiratory Tract Infection          False     10006
# 4                                 Malaria           True     10006
# ...

# %%
df_visits = df_visits.dropna()
df_visits.sample(n=5)
# Out:
#         Visit_Date  Patient_ID  Age  Gender  \
# 250695  2020-05-12      651431   30  Female
# 334299  2019-12-11      528454    2    Male
# 964250  2020-10-18      909064   26    Male
# 869341  2018-04-11      486650   50    Male
# 257520  2021-02-23      647490   28    Male
#
#                                 Diagnosis  Has_Insurance  Postcode  \
# 250695  Upper Respiratory Tract Infection          False     10004
# 334299                     Abdominal pain          False     10014
# 964250                           Backpain           True     10004
# 869341            Urinary Tract Infection          False     10008
# 257520                           Backpain           True     20004
#
#         Total_Cost  Registration  Nursing  Laboratory  Consultation  Pharmacy
# 250695      3030.0            46       89          22            48        98
# 334299      2410.0            58       15          85            44        39
# ...

# %%
df_visits.rename(columns={'Registration': 'Registration_minutes'})
# Out:
#         Visit_Date  Patient_ID  Age  Gender  \
# 0       2020-05-06      688923   68  Female
# 1       2018-08-04      886361   62  Female
# 2       2021-04-10      464823   70  Female
# 3       2021-10-01      655214    8  Female
# 4       2018-04-30      454666   24    Male
# ...            ...         ...  ...     ...
# 999995  2018-09-30      385435    9    Male
# 999996  2020-05-08      117261   29  Female
# 999997  2019-12-31      594613   39  Female
# 999998  2019-11-04      152179   39  Female
# 999999  2019-05-11      370584   76  Female
#
#                                 Diagnosis  Has_Insurance  Postcode  \
# 0                                Diabetes           True     20006
# 1                 Urinary Tract Infection          False     20005
# 2       Upper Respiratory Tract Infection           True     10003
# 3       Upper Respiratory Tract Infection          False     10006
# 4                                 Malaria           True     10006
# ...

# %%
df_visits.rename(columns={'Registration': 'Registration_minutes'}, inplace=True)

# %%
df_visits
# Out:
#         Visit_Date  Patient_ID  Age  Gender  \
# 0       2020-05-06      688923   68  Female
# 1       2018-08-04      886361   62  Female
# 2       2021-04-10      464823   70  Female
# 3       2021-10-01      655214    8  Female
# 4       2018-04-30      454666   24    Male
# ...            ...         ...  ...     ...
# 999995  2018-09-30      385435    9    Male
# 999996  2020-05-08      117261   29  Female
# 999997  2019-12-31      594613   39  Female
# 999998  2019-11-04      152179   39  Female
# 999999  2019-05-11      370584   76  Female
#
#                                 Diagnosis  Has_Insurance  Postcode  \
# 0                                Diabetes           True     20006
# 1                 Urinary Tract Infection          False     20005
# 2       Upper Respiratory Tract Infection           True     10003
# 3       Upper Respiratory Tract Infection          False     10006
# 4                                 Malaria           True     10006
# ...

# %%
column_mapping = {
    'Nursing': 'Nursing_minutes',
    'Laboratory': 'Laboratory_minutes',
    'Consultation': 'Consultation_minutes',
    'Pharmacy': 'Pharmacy_minutes'
}

# %%
df_visits.rename(columns=column_mapping, inplace=True)
df_visits
# Out:
#         Visit_Date  Patient_ID  Age  Gender  \
# 0       2020-05-06      688923   68  Female
# 1       2018-08-04      886361   62  Female
# 2       2021-04-10      464823   70  Female
# 3       2021-10-01      655214    8  Female
# 4       2018-04-30      454666   24    Male
# ...            ...         ...  ...     ...
# 999995  2018-09-30      385435    9    Male
# 999996  2020-05-08      117261   29  Female
# 999997  2019-12-31      594613   39  Female
# 999998  2019-11-04      152179   39  Female
# 999999  2019-05-11      370584   76  Female
#
#                                 Diagnosis  Has_Insurance  Postcode  \
# 0                                Diabetes           True     20006
# 1                 Urinary Tract Infection          False     20005
# 2       Upper Respiratory Tract Infection           True     10003
# 3       Upper Respiratory Tract Infection          False     10006
# 4                                 Malaria           True     10006
# ...

# %%
# df_visits.to_csv('data/clean/Demo Hospital Outpatient Data Clean_NHC.csv')
# index set to false to avoid unnamed indexing
df_visits.to_csv('data/clean/Demo Hospital Outpatient Data Clean_NHC.csv', index=False)

# %%
pd.read_csv('data/clean/Demo Hospital Outpatient Data Clean_NHC.csv')
# Out:
#         Visit_Date  Patient_ID  Age  Gender  \
# 0       2020-05-06      688923   68  Female
# 1       2018-08-04      886361   62  Female
# 2       2021-04-10      464823   70  Female
# 3       2021-10-01      655214    8  Female
# 4       2018-04-30      454666   24    Male
# ...            ...         ...  ...     ...
# 999995  2018-09-30      385435    9    Male
# 999996  2020-05-08      117261   29  Female
# 999997  2019-12-31      594613   39  Female
# 999998  2019-11-04      152179   39  Female
# 999999  2019-05-11      370584   76  Female
#
#                                 Diagnosis  Has_Insurance  Postcode  \
# 0                                Diabetes           True     20006
# 1                 Urinary Tract Infection          False     20005
# 2       Upper Respiratory Tract Infection           True     10003
# 3       Upper Respiratory Tract Infection          False     10006
# 4                                 Malaria           True     10006
# ...

# %%
df_visits.to_excel('data/clean/Demo Hospital Outpatient Data Clean_NHC.xlsx', index=False)

# %%
pd.read_excel('data/clean/Demo Hospital Outpatient Data Clean_NHC.xlsx')
# Out:
#         Visit_Date  Patient_ID  Age  Gender  \
# 0       2020-05-06      688923   68  Female
# 1       2018-08-04      886361   62  Female
# 2       2021-04-10      464823   70  Female
# 3       2021-10-01      655214    8  Female
# 4       2018-04-30      454666   24    Male
# ...            ...         ...  ...     ...
# 999995  2018-09-30      385435    9    Male
# 999996  2020-05-08      117261   29  Female
# 999997  2019-12-31      594613   39  Female
# 999998  2019-11-04      152179   39  Female
# 999999  2019-05-11      370584   76  Female
#
#                                 Diagnosis  Has_Insurance  Postcode  \
# 0                                Diabetes           True     20006
# 1                 Urinary Tract Infection          False     20005
# 2       Upper Respiratory Tract Infection           True     10003
# 3       Upper Respiratory Tract Infection          False     10006
# 4                                 Malaria           True     10006
# ...

# %%
import zipfile

# %%
zipped_file_name = 'demo_hospital_outpatient_data_clean.zip'

# %%
with zipfile.ZipFile(zipped_file_name, 'w', zipfile.ZIP_DEFLATED) as zip:
    zip.write('data/clean/Demo Hospital Outpatient Data Clean_NHC.csv')

# %%
pd.read_csv('data/clean/demo_hospital_outpatient_data_clean.zip')
# Out:
#         Visit_Date  Patient_ID  Age  Gender  \
# 0       2020-05-06      688923   68  Female
# 1       2018-08-04      886361   62  Female
# 2       2021-04-10      464823   70  Female
# 3       2021-10-01      655214    8  Female
# 4       2018-04-30      454666   24    Male
# ...            ...         ...  ...     ...
# 999995  2018-09-30      385435    9    Male
# 999996  2020-05-08      117261   29  Female
# 999997  2019-12-31      594613   39  Female
# 999998  2019-11-04      152179   39  Female
# 999999  2019-05-11      370584   76  Female
#
#                                 Diagnosis  Has_Insurance  Postcode  \
# 0                                Diabetes           True     20006
# 1                 Urinary Tract Infection          False     20005
# 2       Upper Respiratory Tract Infection           True     10003
# 3       Upper Respiratory Tract Infection          False     10006
# 4                                 Malaria           True     10006
# ...

# %%
# !pip install pyreadstat
# Out:
# ...
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.4 MB 5.6 MB/s eta 0:00:01
#    ----------------- ---------------------- 1.0/2.4 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.1/2.4 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.1/2.4 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.4/2.4 MB 2.9 MB/s eta 0:00:00
# ...

# %%
import pyreadstat

# %%
spss_file = 'demo_hospital_outpatient_data_clean.sav'

# %%
pyreadstat.write_sav(df_visits, spss_file)

# %%
data, meta = pyreadstat.read_sav('data/clean/demo_hospital_outpatient_data_clean.sav')

# %%
data
# Out:
#         Visit_Date  Patient_ID   Age  Gender  \
# 0       2020-05-06    688923.0  68.0  Female
# 1       2018-08-04    886361.0  62.0  Female
# 2       2021-04-10    464823.0  70.0  Female
# 3       2021-10-01    655214.0   8.0  Female
# 4       2018-04-30    454666.0  24.0    Male
# ...            ...         ...   ...     ...
# 999995  2018-09-30    385435.0   9.0    Male
# 999996  2020-05-08    117261.0  29.0  Female
# 999997  2019-12-31    594613.0  39.0  Female
# 999998  2019-11-04    152179.0  39.0  Female
# 999999  2019-05-11    370584.0  76.0  Female
#
#                                 Diagnosis  Has_Insurance  Postcode  \
# 0                                Diabetes            1.0   20006.0
# 1                 Urinary Tract Infection            0.0   20005.0
# 2       Upper Respiratory Tract Infection            1.0   10003.0
# 3       Upper Respiratory Tract Infection            0.0   10006.0
# 4                                 Malaria            1.0   10006.0
# ...

# %%
meta

# %%
df_visits = pd.DataFrame(data)
